# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
chargers = pd.read_csv('superchargers.csv')
chargers.head(10)
# Out:
#                               name                      address  \
# 0  Miami - South Dixie Highway, FL           8312 Dixie Highway
# 1                Mackinaw City, MI              801 S Huron Ave
# 2                Hermosa Beach, CA                  710 16th St
# 3                  Pismo Beach, CA           333 Five Cities Dr
# 4         Richmond - Pierce St, CA               3288 Pierce St
# 5                        Kelso, WA          205 Three Rivers Dr
# 6                        Fargo, ND              5680 23rd Ave S
# 7                       Easton, MD           7655 Ocean Gateway
# 8                      Emporia, KS           1330 Industrial Rd
# 9               St. Louis Park, MN  3601 State Hwy 100 (MN-100)
#
#              city state    zip country  num_stalls  power  \
# 0           Miami    FL  33143     USA          12   72.0
# 1   Mackinaw City    MI  49701     USA           8  250.0
# 2   Hermosa Beach    CA  90254     USA          20  250.0
# 3     Pismo Beach    CA  93449     USA          12  250.0
# 4        Richmond    CA  94804     USA          12  250.0
# 5           Kelso    WA  98626     USA          12  250.0
# 6           Fargo    ND  58104     USA           4  250.0
# 7          Easton    MD  21601     USA           8  250.0
# 8         Emporia    KS  66801     USA           8  250.0
# 9  St. Louis Park    MN  55416     USA           8  250.0
#
#                   lat_lon  elevation status   open_date
# 0   25.693198, -80.304898          3   OPEN  2020-06-11
# 1      45.77225, -84.7265        180   OPEN  2020-06-10
# 2  33.864955, -118.394819         25   OPEN  2020-06-10
# 3  35.136408, -120.628662         12   OPEN  2020-06-08
# 4  37.898736, -122.308672          4   OPEN  2020-05-30
# 5  46.143403, -122.899225          6   OPEN  2020-05-29
# 6   46.843601, -96.882492        276   OPEN  2020-05-29
# 7   38.759257, -76.061405         13   OPEN  2020-05-28
# 8   38.414266, -96.216714        354   OPEN  2020-05-28
# 9   44.935964, -93.347857        269   OPEN  2020-05-27

# %%
# Clean up the lat/lon data
chargers[['lat', 'lon']] = chargers['lat_lon'].str.split(expand=True)
chargers['lat'] = chargers['lat'].apply(lambda x: x.replace(',','')).astype(float)
chargers['lon'] = chargers['lon'].apply(lambda x: x.replace(',','')).astype(float)
chargers = chargers.drop(columns=['lat_lon'])

# %%
# States with the most chargering stations available
fig, ax = plt.subplots(figsize=(20,10))
stations_per_state = chargers.groupby('state')['name'].count().sort_values(ascending=False)
ax.bar(stations_per_state.index, stations_per_state.values)
ax.grid()

# %%
# States with the most charging stalls available
fig, ax = plt.subplots(figsize=(20,10))
stalls_per_state = chargers.groupby('state')['num_stalls'].sum().sort_values(ascending=False)
ax.bar(stalls_per_state.index, stalls_per_state.values)
ax.grid()
